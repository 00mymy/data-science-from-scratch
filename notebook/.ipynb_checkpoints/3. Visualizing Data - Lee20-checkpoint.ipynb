# %% [markdown]
# # 개요
# + matplotlib를 이용한 기본적인 시각화
# + Line Chart, Bar Chart, Scatter Plot

# %% [markdown]
# # matplotlib - 그래프 그리기
# + 각종 데이터 그래프 그리는 도구
#   - line, bar(수직/수평), area, scatter, pie 등
#   - 다양한 chart option

# %% [markdown]
# ## 일단 그려보기 - Line Chart
# * 이동국 연도별 K리그 득점 (리그 + 리그컵)
# * 데이터 출처
#   + http://www.yonhapnews.co.kr/bulletin/2017/09/19/0200000000AKR20170919095500007.HTML
#   + https://namu.wiki/w/%EC%9D%B4%EB%8F%99%EA%B5%AD

# %%
from matplotlib import pyplot as plt

years = [year for year in range(1998,2019)]
goals = [11,8,4,4,10,11,4,7,7,1,8,26,13,16,28,15,13,14,12,10, 13] #1998~2018 이동국 시즌 득점수 (리그+FA컵+리그컵+대륙대회)
games = [24,19,8,26,25,27,25,28,10,24,18,36,40,38,48,40,40,41,41,31,45]


plt.plot(years, goals)
plt.plot(years, games)

plt.show()

# %% [markdown]
# ### 시각화 튜닝하기 - plot options
# + 어떤 옵션들이 있는가?
#   - help()

# %%
help(plt)
# Out:
# Help on module matplotlib.pyplot in matplotlib:
#
# NAME
#     matplotlib.pyplot
#
# DESCRIPTION
#     `matplotlib.pyplot` is a state-based interface to matplotlib. It provides
#     a MATLAB-like way of plotting.
#
#     pyplot is mainly intended for interactive plots and simple cases of programmatic
#     plot generation::
#
#         import numpy as np
#         import matplotlib.pyplot as plt
#
#         x = np.arange(0, 5, 0.1)
#         y = np.sin(x)
#         plt.plot(x, y)
#
#     The object-oriented API is recommended for more complex plots.
#
# FUNCTIONS
#     acorr(x, hold=None, data=None, **kwargs)
#         Plot the autocorrelation of `x`.
#
#         Parameters
#         ----------
#
#         x : sequence of scalar
#
#         hold : boolean, optional, *deprecated*, default: True
#
#         detrend : callable, optional, default: `mlab.detrend_none`
#             x is detrended by the `detrend` callable. Default is no
#             normalization.
#
# ...

# %%
# 한글 깨짐 해결
from matplotlib import font_manager, rc
font_fname = 'c:/windows/fonts/malgun.ttf'     # A font of your choice
font_name = font_manager.FontProperties(fname=font_fname).get_name()
rc('font', family=font_name)

# create a line chart, years on x-axis, gdp on y-axis
plt.plot(years, goals, color='r', marker='^', linestyle=':')
plt.title("연도별 득점수")
plt.ylabel("득점수")
plt.xlabel("연도")
plt.show()


plt.plot(years, games, color='b', marker='^', linestyle=':')
plt.title("연도별 출전수")
plt.ylabel("출전수")
plt.xlabel("연도")
plt.show()


'''
plt.subplot(1, 2, 1)
plt.plot(years, goals, color='r', marker='^', linestyle=':')
plt.title("연도별 득점수")
plt.ylabel("득점수")
plt.xlabel("연도")

plt.subplot(1, 2, 2)
plt.plot(years, games, color='b', marker='^', linestyle=':')
plt.title("연도별 출전수")
plt.ylabel("출전수")
plt.xlabel("연도")
plt.show()

'''

plt.plot(years, goals, 'g-',  label='Goals')    # green solid line
plt.plot(years, games, 'r:', label='Games')      # red dot-dashed line
plt.legend(loc=9)
plt.title("연도별 출전수 및 득점수")
plt.ylabel("출전수-득점수")
plt.xlabel("연도")
plt.show()

# %% [markdown]
# # Bar 차트
# + 소속팀별 득점수 (~2018)
# + 추이를 보기 보다는 항목별로 비교할 때 적합

# %%
goals_ph = [11,8,4,3,7,7,7] #포항
goals_sm = [11,4,0]         #상무
goals_md = [1,1]            #미들스브러
goals_sn = [2]              #성남
goals_jb = [22,13,16,26,13,13,13,12,10, 13] #전북


##########################################################################################
#소속팀별 득점
# 데이터 출처 
# http://www.yonhapnews.co.kr/bulletin/2017/09/19/0200000000AKR20170919095500007.HTML
# https://namu.wiki/w/%EC%9D%B4%EB%8F%99%EA%B5%AD
teams = ["포항", "상무", "미들스브러", "성남", "전북"]
team_goals = [sum(goals_ph),sum(goals_sm),sum(goals_md),sum(goals_sn),sum(goals_jb)]

# %% [markdown]
# ### 대충 그리면...
# + 라인 차트는 주어진 데이터를 잘 표현하는가?

# %%
plt.plot(teams, team_goals)

# %% [markdown]
# ### 제대로 그리기
# + line &rarr; bar
# + xticks()
#   - X축 레이블 맞추기

# %%
# 무작정 그리니까 가나다순으로 그리고 자빠졌네
plt.bar(teams, team_goals)
plt.show()


# 팀 명은 따로 붙이도록 그리자
# plot bars with left x-coordinates [0, 1, 2, 3, 4], heights [num_oscars]
plt.bar(range(len(teams)), team_goals)

# 원본의 텍스트를 그대로 출력 (45도 기울이는게 좋을듯)
#plt.bar(movies, num_oscars)
#plt.xticks(rotation=45)

plt.title("소속팀별 득점수")     # add a title
plt.ylabel("득점수")   # label the y-axis

# label x-axis with team names at bar centers
plt.xticks(range(len(teams)), teams)

plt.show()

# %% [markdown]
# # 히스토그램
# + 시즌별 출전수 데이터
# + 시즌 출전 경기수를 구간별 히스토그램으로 시각화
#   - x축: 경기수구간 (5경기 이하, 5~10, 10~15, ...)
#   - y축: 해당 경기수 구간에 속하는 시즌수

# %%
from collections import Counter

# %% [markdown]
# ### 데이터 전처리/변환
# + 원시 데이터 &rarr; 구간 데이터
# + 구간에 맞게 Bar chart를 그리도록 x축 위치 조정

# %%
# Bucket grades by decile, but put 100 in with the 90s
#histogram = Counter(min(game // 5 * 5, 50) for game in games)
histogram = Counter(game // 5 * 5 for game in games)

# %%
plt.bar([x + 2.5 for x in histogram.keys()],  # Shift bars right by 5
        histogram.values(),                 # Give each bar its correct height
        4,                                 # Give each bar a width of 10
        edgecolor=(0, 0, 0))                # Black edges for each bar

plt.axis([0, 55, 0, 10])                  # x-axis from -5 to 105,
                                           # y-axis from 0 to 5

plt.xticks([5 * i for i in range(11)])    # x-axis labels at 0, 10, ..., 100
plt.xlabel("Played Games")
plt.ylabel("# of Seasons")
plt.title("Distribution of Season Games")
plt.show()

# %% [markdown]
# ## 왜곡된 시각화 - 같은 데이터, 다른 시각화
# + 시각화의 장단점
#   - 장) 분포, 양, 추이를 빠르게 파악
#   - 단) 데이터를 잘못 이해할 수 있다 (보이는게 전부가 아님)

# %% [markdown]
# ### 시즌별 득점수 분포

# %%
plt.bar(years, goals)

plt.xlabel("Played Games")
plt.ylabel("# of Goals")
plt.title("Distribution of Season Goals")
plt.show()

# %% [markdown]
# ### 작은 차이!
# + y축의 범위를 제대로
# + 예) 2010 vs. 2012

# %%
years_4 = [ 2009, 2010, 2011, 2012]
goals_4 = [26, 13, 16, 28]

plt.bar(years_4, goals_4)
plt.xticks(years_4)
plt.axis([2008.5, 2012.5, 0, 30])
plt.xlabel("Played Games")
plt.ylabel("# of Goals")
plt.title("Distribution of Season Goals")
plt.show()

# %% [markdown]
# ### 큰 차이 ?
# * y축의 범위를 왜곡
# * 예) 2010 vs. 2012 &rarr; 차이가 더 커보인다
#   + 실제로는 2배 수준 차이지만, 시각적으로는 몇 배 더 차이나는 것처럼...

# %%
plt.bar(years_4, goals_4)
plt.xticks(years_4)
plt.axis([2008.5, 2012.5, 10, 30])
plt.xlabel("Played Games")
plt.ylabel("# of Goals")
plt.title("Distribution of Season Goals")
plt.show()

# %% [markdown]
# # Line Charts
# + 여러 데이터 셋 비교
# + 데이터 셋 구분 (컬러, 레이블, 스타일 등)
# + 범례 보여주기

# %%
variance     = [1, 2, 4, 8, 16, 32, 64, 128, 256]
bias_squared = [256, 128, 64, 32, 16, 8, 4, 2, 1]
total_error  = [x + y for x, y in zip(variance, bias_squared)]
xs = [i for i, _ in enumerate(variance)]

# We can make multiple calls to plt.plot
# to show multiple series on the same chart
plt.plot(xs, variance,     'g-',  label='variance')    # green solid line
plt.plot(xs, bias_squared, 'r-.', label='bias^2')      # red dot-dashed line
plt.plot(xs, total_error,  'b:',  label='total error') # blue dotted line

# Because we've assigned labels to each series,
# we can get a legend for free (loc=9 means "top center")
plt.legend(loc=9)
plt.xlabel("model complexity")
plt.xticks([])
plt.title("The Bias-Variance Tradeoff")
plt.show()

# %% [markdown]
# # Scatterplots
# + 두 데이터 셋의 분포와 상관관계 시각화

# %%
plt.scatter(goals, games)

# label each point
for year, year_goals, year_games in zip(years, goals, games):
    plt.annotate(year,
        xy=(year_goals, year_games), # Put the label with its point
        xytext=(5, -5),                  # but slightly offset
        textcoords='offset points')

plt.title("Goals & Played Games")
plt.xlabel("# of goals")
plt.ylabel("# of played games")
plt.show()


plt.scatter(games, goals)
# label each point
for year, year_goals, year_games in zip(years, goals, games):
    plt.annotate(year,
        xy=(year_games, year_goals), # Put the label with its point
        xytext=(5, -5),                  # but slightly offset
        textcoords='offset points')

plt.title("Goals & Played Games")
plt.xlabel("# of played games")
plt.ylabel("# of goals")
plt.show()

# %% [markdown]
# # 참고 - Boxplot
# + 데이터의 분포와 특징을 한 번에 시각화
# + 평균, 중간값, 분위값 범위, 이상치(Outlier)

# %%
# Boxplot
test_1_grades = [85, 60, 90, 70, 99, 90, 85, 97, 80, 120]
test_2_grades = [35, 100, 85, 60, 90, 70, 70, 99, 90, 85, 97]
plt.boxplot([test_1_grades, test_2_grades],  0, 'bD', showmeans=True)
plt.show()

# %% [markdown]
# ## Boxplot - Options

# %%
import numpy as np
#import matplotlib.pyplot as plt

# fake data
np.random.seed(937)
data = np.random.lognormal(size=(37, 4), mean=1.5, sigma=1.75)
#data = np.random.normal(size=(37, 4), loc=1.5, scale=1.75)
labels = list('ABCD')
fs = 10  # fontsize


plt.boxplot(data, labels=labels, showmeans=True, showfliers=False, notch=True, bootstrap=10000)
plt.show()


# demonstrate how to toggle the display of different elements:

fig, axes = plt.subplots(nrows=2, ncols=3, figsize=(6, 6), sharey=True)
axes[0, 0].boxplot(data, labels=labels)
axes[0, 0].set_title('Default', fontsize=fs)

axes[0, 1].boxplot(data, labels=labels, showmeans=True)
axes[0, 1].set_title('showmeans=True', fontsize=fs)

axes[0, 2].boxplot(data, labels=labels, showmeans=True, meanline=True)
axes[0, 2].set_title('showmeans=True,\nmeanline=True', fontsize=fs)

axes[1, 0].boxplot(data, labels=labels, showbox=False, showcaps=False)
tufte_title = 'Tufte Style \n(showbox=False,\nshowcaps=False)'
axes[1, 0].set_title(tufte_title, fontsize=fs)

axes[1, 1].boxplot(data, labels=labels, notch=True, bootstrap=10000)
axes[1, 1].set_title('notch=True,\nbootstrap=10000', fontsize=fs)

axes[1, 2].boxplot(data, labels=labels, showfliers=False)
axes[1, 2].set_title('showfliers=False', fontsize=fs)

for ax in axes.flatten():
    ax.set_yscale('log')
    ax.set_yticklabels([])

fig.subplots_adjust(hspace=.4)
plt.show()

# %% [markdown]
# # 참고 - 3D 시각화

# %%
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
import numpy as np


def randrange(n, vmin, vmax):
    '''
    Helper function to make an array of random numbers having shape (n, )
    with each number distributed Uniform(vmin, vmax).
    '''
    return (vmax - vmin)*np.random.rand(n) + vmin

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

n = 100

# For each set of style and range settings, plot n random points in the box
# defined by x in [23, 32], y in [0, 100], z in [zlow, zhigh].
for c, m, zlow, zhigh in [('r', 'o', -50, -25), ('b', '^', -30, -5)]:
    xs = randrange(n, 23, 32)
    ys = randrange(n, 0, 100)
    zs = randrange(n, zlow, zhigh)
    ax.scatter(xs, ys, zs, c=c, marker=m)

ax.set_xlabel('X Label')
ax.set_ylabel('Y Label')
ax.set_zlabel('Z Label')

plt.show()

# %% [markdown]
# # 참고 - Word Cloud

# %%
from wordcloud import WordCloud


# Read the whole text.
text = '''Data scientist has been called “the sexiest job of the 21st century,” presumably by
someone who has never visited a fire station. Nonetheless, data science is a hot and
growing field, and it doesn’t take a great deal of sleuthing to find analysts breathlessly
prognosticating that over the next 10 years, we’ll need billions and billions more data
scientists than we currently have.'''

# Generate a word cloud image
wordcloud = WordCloud().generate(text)

# Display the generated image:
# the matplotlib way:
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")

# lower max_font_size
wordcloud = WordCloud(max_font_size=40).generate(text)
plt.figure()
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.show()
